# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [01:05, 2.59MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 3

sample_id = 113
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 3:
# Samples: 10000
# Label Counts: {0: 994, 1: 1042, 2: 965, 3: 997, 4: 990, 5: 1029, 6: 978, 7: 1015, 8: 961, 9: 1029}
# First 20 Labels: [8, 5, 0, 6, 9, 2, 8, 3, 6, 2, 7, 4, 6, 9, 0, 0, 7, 3, 7, 2]
#
# Example of Image 113:
# Image - Min Value: 0 Max Value: 226
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/255.


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
from sklearn import preprocessing

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function

    # CIFAR has 10 labels we need to prepare for
    labels = np.arange(0,10)
    
    # We create a LabelBinarizer as suggested in the Hint above and format it for our 10 keys
    lb = preprocessing.LabelBinarizer()
    lb.fit(labels)
    
    # We act upon the input labels, now that our lb is properly fit
    return lb.transform(x)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    x = tf.placeholder(tf.float32, [None, image_shape[0], image_shape[1], image_shape[2]], name='x')
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.float32, [None, n_classes], name='y')
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    kp = tf.placeholder(tf.float32, name='keep_prob')
    return kp


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    
    # We need to create the weights and biases
    # In order to do this, we need to figure out the input depth, which we will pull from 
    # the input tensor shape, which has the format (b, w, h, input_depth)
    tensor_shape = x_tensor.get_shape().as_list()
    weights = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], tensor_shape[3], conv_num_outputs], \
                                              stddev=0.2), name="weights")
    biases = tf.Variable(tf.zeros([conv_num_outputs]), name="biases")

    # Now we can create the conv2d layer, add the bias, and add nonlinear activation (reLu)
    output = tf.nn.conv2d(x_tensor, weights, strides=[1,conv_strides[0],conv_strides[1],1], padding='SAME')
    output = tf.nn.bias_add(output, biases)
    output = tf.nn.relu(output)
    
    # Now we need to add max_pooling
    output = tf.nn.max_pool(output, ksize=[1, pool_ksize[0], pool_ksize[1], 1], \
                            strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME' )
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    tensor_size = x_tensor.get_shape().as_list()
    #print(len(tensor_size))
    assert len(tensor_size) >= 4
    
    total_features_per_record = tensor_size[1] * tensor_size[2] * tensor_size[3]
    #print(total_features_per_record)
    
    flat = tf.reshape(x_tensor, [-1, total_features_per_record ])
    return flat

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# 4
# 1800
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    # since the first dimension is batch size, the 2nd dimension is inputs
    tensor_size = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.truncated_normal([tensor_size, num_outputs], stddev=0.2))
    biases = tf.Variable(tf.zeros([num_outputs]))
    output = tf.nn.relu(\
                       tf.add(\
                                tf.matmul(x_tensor, weights),
                                biases)
                       )    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    # similar to above fully_conv()
    tensor_size = x_tensor.get_shape().as_list()[1]
    weights = tf.Variable(tf.truncated_normal([tensor_size, num_outputs], stddev=0.2))
    biases = tf.Variable(tf.zeros([num_outputs]))
    output = tf.add( tf.matmul(x_tensor, weights), biases)
    return output
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    out = conv2d_maxpool(x, 32, conv_ksize=[2, 2], conv_strides=[2, 2], pool_ksize=[1,1], pool_strides=[1,1])
    out = conv2d_maxpool(out, 64, conv_ksize=[2, 2], conv_strides=[2, 2], pool_ksize=[1,1], pool_strides=[1,1])
    out = conv2d_maxpool(out, 128, conv_ksize=[2, 2], conv_strides=[2,2], pool_ksize=[1,1], pool_strides=[1,1])
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    out = flatten(out)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    out = fully_conn(out, 512)
    out = fully_conn(out, 256)

    # APPLY DROPOUT
    out = tf.nn.dropout(out, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(out, 10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# 4
# 2048
# 4
# 2048
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})
    

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = sess.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1. })
    acc = sess.run(accuracy, feed_dict={x: valid_features, y:valid_labels, keep_prob: 1.})
    print('Loss: {:>10.4f} Validation Accuracy:{:.6f}'.format(loss, acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = .45

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.3016 Validation Accuracy:0.177400
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.0722 Validation Accuracy:0.214800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.9574 Validation Accuracy:0.237400
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.8611 Validation Accuracy:0.272000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.7476 Validation Accuracy:0.289600
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.6582 Validation Accuracy:0.318400
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.5831 Validation Accuracy:0.339600
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.4448 Validation Accuracy:0.359800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.3585 Validation Accuracy:0.370800
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.2294 Validation Accuracy:0.377200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.1435 Validation Accuracy:0.383600
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.0472 Validation Accuracy:0.388600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.9202 Validation Accuracy:0.396800
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.8482 Validation Accuracy:0.407400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.7926 Validation Accuracy:0.414200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.7063 Validation Accuracy:0.422600
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.6278 Validation Accuracy:0.422600
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.5538 Validation Accuracy:0.434000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.4820 Validation Accuracy:0.432600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.4686 Validation Accuracy:0.437200
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.4359 Validation Accuracy:0.446800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.3839 Validation Accuracy:0.431800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.3563 Validation Accuracy:0.446600
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.2998 Validation Accuracy:0.457400
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.2798 Validation Accuracy:0.448000
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.2531 Validation Accuracy:0.470600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.2193 Validation Accuracy:0.450000
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.1822 Validation Accuracy:0.458400
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.1776 Validation Accuracy:0.469800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.1768 Validation Accuracy:0.447600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.1639 Validation Accuracy:0.449400
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.1378 Validation Accuracy:0.471400
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.1332 Validation Accuracy:0.471400
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.1091 Validation Accuracy:0.470400
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0914 Validation Accuracy:0.462400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0670 Validation Accuracy:0.475800
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0516 Validation Accuracy:0.482400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0568 Validation Accuracy:0.484200
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0289 Validation Accuracy:0.479600
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0316 Validation Accuracy:0.489800
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0323 Validation Accuracy:0.489600
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0198 Validation Accuracy:0.488200
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0133 Validation Accuracy:0.481600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0150 Validation Accuracy:0.489600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0098 Validation Accuracy:0.484600
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0098 Validation Accuracy:0.479400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0060 Validation Accuracy:0.480400
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0064 Validation Accuracy:0.481400
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0049 Validation Accuracy:0.477000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0039 Validation Accuracy:0.477400
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0040 Validation Accuracy:0.490800
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0042 Validation Accuracy:0.483400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0023 Validation Accuracy:0.490200
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0040 Validation Accuracy:0.490200
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0016 Validation Accuracy:0.489200
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0017 Validation Accuracy:0.495600
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0018 Validation Accuracy:0.484400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0013 Validation Accuracy:0.486600
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy:0.489800
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy:0.494800
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy:0.486000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy:0.491800
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy:0.488000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0015 Validation Accuracy:0.468400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy:0.478400
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy:0.485000
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy:0.490600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy:0.487600
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy:0.486800
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy:0.493800
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy:0.491800
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.491000
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.493200
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy:0.492000
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.481000
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.486800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.478800
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.479600
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.496600
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.497600
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.496600
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.498400
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.502200
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.500000
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.499600
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.494400
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.498200
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.499400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.507200
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.504400
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.504200
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.508600
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.496200
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.504400
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.507800
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.501000
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.504000
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.502400
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.498600
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.507600

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2604 Validation Accuracy:0.181800
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.1473 Validation Accuracy:0.216800
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.0099 Validation Accuracy:0.249200
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.0360 Validation Accuracy:0.280400
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.9447 Validation Accuracy:0.302000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     2.0111 Validation Accuracy:0.331800
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.8316 Validation Accuracy:0.353200
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.6383 Validation Accuracy:0.345000
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.6834 Validation Accuracy:0.368000
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.6151 Validation Accuracy:0.375800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.7748 Validation Accuracy:0.396600
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.6574 Validation Accuracy:0.407800
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.3557 Validation Accuracy:0.398000
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.5008 Validation Accuracy:0.409200
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.5041 Validation Accuracy:0.412600
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.6088 Validation Accuracy:0.414000
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.3603 Validation Accuracy:0.435000
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.1763 Validation Accuracy:0.439200
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.4040 Validation Accuracy:0.447800
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.3681 Validation Accuracy:0.449400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.4258 Validation Accuracy:0.441800
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.2051 Validation Accuracy:0.475600
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.9945 Validation Accuracy:0.469400
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.3245 Validation Accuracy:0.476800
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.1832 Validation Accuracy:0.481000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.2611 Validation Accuracy:0.479200
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.0968 Validation Accuracy:0.490000
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.7935 Validation Accuracy:0.490800
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.1475 Validation Accuracy:0.492600
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.0648 Validation Accuracy:0.498200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.1388 Validation Accuracy:0.492800
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.9469 Validation Accuracy:0.504000
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.7264 Validation Accuracy:0.505800
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.0298 Validation Accuracy:0.525800
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.9467 Validation Accuracy:0.509200
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.9787 Validation Accuracy:0.503400
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.7973 Validation Accuracy:0.522200
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.6445 Validation Accuracy:0.531200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.9008 Validation Accuracy:0.526800
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.8211 Validation Accuracy:0.529800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.9463 Validation Accuracy:0.525000
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.7087 Validation Accuracy:0.533200
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.4677 Validation Accuracy:0.533600
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.7881 Validation Accuracy:0.543600
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.7421 Validation Accuracy:0.550000
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.7774 Validation Accuracy:0.534800
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.5928 Validation Accuracy:0.539800
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.4644 Validation Accuracy:0.545800
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.7071 Validation Accuracy:0.545800
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.6447 Validation Accuracy:0.554200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.7143 Validation Accuracy:0.558400
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.5091 Validation Accuracy:0.551800
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.3591 Validation Accuracy:0.556800
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.5794 Validation Accuracy:0.560400
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.5813 Validation Accuracy:0.555800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.6084 Validation Accuracy:0.564000
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.3953 Validation Accuracy:0.562200
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.3150 Validation Accuracy:0.557800
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.4856 Validation Accuracy:0.566600
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.4094 Validation Accuracy:0.572400
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.5640 Validation Accuracy:0.576000
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.3533 Validation Accuracy:0.566800
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.2109 Validation Accuracy:0.579400
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.4593 Validation Accuracy:0.569000
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.3621 Validation Accuracy:0.568600
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.4826 Validation Accuracy:0.580600
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.3102 Validation Accuracy:0.570200
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.2032 Validation Accuracy:0.580400
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.3386 Validation Accuracy:0.584000
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.3171 Validation Accuracy:0.574600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.4354 Validation Accuracy:0.584400
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.2269 Validation Accuracy:0.579600
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.1411 Validation Accuracy:0.578000
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.2640 Validation Accuracy:0.584800
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.2463 Validation Accuracy:0.582000
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.3779 Validation Accuracy:0.587600
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.1567 Validation Accuracy:0.589800
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.1090 Validation Accuracy:0.580200
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.2117 Validation Accuracy:0.588800
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.1998 Validation Accuracy:0.586200
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.3012 Validation Accuracy:0.594600
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.1467 Validation Accuracy:0.586200
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.0950 Validation Accuracy:0.575800
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.1538 Validation Accuracy:0.592000
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.1617 Validation Accuracy:0.583200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.2825 Validation Accuracy:0.586400
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.1233 Validation Accuracy:0.587600
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.0893 Validation Accuracy:0.586000
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.1448 Validation Accuracy:0.584600
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.1529 Validation Accuracy:0.593000
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.2804 Validation Accuracy:0.583600
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.1030 Validation Accuracy:0.567800
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.0955 Validation Accuracy:0.583400
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.1472 Validation Accuracy:0.593200
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.1191 Validation Accuracy:0.588600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.2363 Validation Accuracy:0.589400
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.0836 Validation Accuracy:0.551400
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.1166 Validation Accuracy:0.575600
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.1322 Validation Accuracy:0.579200
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.1031 Validation Accuracy:0.583400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.2061 Validation Accuracy:0.578800
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.0782 Validation Accuracy:0.539600
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.0677 Validation Accuracy:0.587600
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.1254 Validation Accuracy:0.566800
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.0553 Validation Accuracy:0.598600
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.1885 Validation Accuracy:0.563800
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.0632 Validation Accuracy:0.569000
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.0485 Validation Accuracy:0.600000
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.0765 Validation Accuracy:0.569400
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.0636 Validation Accuracy:0.600000
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.1392 Validation Accuracy:0.590400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.0496 Validation Accuracy:0.596600
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.0346 Validation Accuracy:0.593800
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.0493 Validation Accuracy:0.572600
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.0514 Validation Accuracy:0.596200
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.1163 Validation Accuracy:0.592000
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.0372 Validation Accuracy:0.598800
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.0228 Validation Accuracy:0.592600
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.0569 Validation Accuracy:0.575800
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.0545 Validation Accuracy:0.598800
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0831 Validation Accuracy:0.599000
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.0431 Validation Accuracy:0.603400
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.0201 Validation Accuracy:0.602800
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.0349 Validation Accuracy:0.592600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.0374 Validation Accuracy:0.599400
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0740 Validation Accuracy:0.601600
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.0323 Validation Accuracy:0.596600
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.0119 Validation Accuracy:0.600200
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.0350 Validation Accuracy:0.582200
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.0295 Validation Accuracy:0.589600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0504 Validation Accuracy:0.607200
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.0418 Validation Accuracy:0.580800
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.0104 Validation Accuracy:0.594600
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.0370 Validation Accuracy:0.593800
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.0292 Validation Accuracy:0.580000
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0585 Validation Accuracy:0.608000
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.0320 Validation Accuracy:0.583200
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.0139 Validation Accuracy:0.590400
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.0291 Validation Accuracy:0.594400
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.0094 Validation Accuracy:0.592000
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0444 Validation Accuracy:0.595400
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.0157 Validation Accuracy:0.600200
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.0077 Validation Accuracy:0.600600
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.0305 Validation Accuracy:0.602200
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.0097 Validation Accuracy:0.598800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0216 Validation Accuracy:0.595600
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.0073 Validation Accuracy:0.576400
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.0057 Validation Accuracy:0.601000
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.0156 Validation Accuracy:0.592800
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.0075 Validation Accuracy:0.590200
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0255 Validation Accuracy:0.600400
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.0113 Validation Accuracy:0.581400
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.0061 Validation Accuracy:0.608000
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.0410 Validation Accuracy:0.591600
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.0056 Validation Accuracy:0.597200
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0240 Validation Accuracy:0.601600
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.0072 Validation Accuracy:0.568000
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.0068 Validation Accuracy:0.600200
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.0181 Validation Accuracy:0.607200
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.0036 Validation Accuracy:0.594600
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0209 Validation Accuracy:0.597600
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.0015 Validation Accuracy:0.585600
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.0048 Validation Accuracy:0.609000
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.0208 Validation Accuracy:0.599000
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.0032 Validation Accuracy:0.602600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0164 Validation Accuracy:0.586600
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.0032 Validation Accuracy:0.585600
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.0032 Validation Accuracy:0.600800
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.0238 Validation Accuracy:0.588200
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.0013 Validation Accuracy:0.603000
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0182 Validation Accuracy:0.587000
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.0019 Validation Accuracy:0.583200
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.0041 Validation Accuracy:0.584800
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.0143 Validation Accuracy:0.594600
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.0008 Validation Accuracy:0.607200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0127 Validation Accuracy:0.584600
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.0018 Validation Accuracy:0.588800
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.0042 Validation Accuracy:0.590200
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.0074 Validation Accuracy:0.598600
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.0017 Validation Accuracy:0.609000
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0117 Validation Accuracy:0.601400
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.0009 Validation Accuracy:0.602400
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.0021 Validation Accuracy:0.595600
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.0027 Validation Accuracy:0.589000
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.0007 Validation Accuracy:0.604600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0107 Validation Accuracy:0.606000
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.0014 Validation Accuracy:0.597000
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.0028 Validation Accuracy:0.589800
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.0058 Validation Accuracy:0.588400
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0008 Validation Accuracy:0.604800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0038 Validation Accuracy:0.604400
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.0009 Validation Accuracy:0.588200
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.0019 Validation Accuracy:0.604800
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.0027 Validation Accuracy:0.598000
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.0012 Validation Accuracy:0.606400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0031 Validation Accuracy:0.610400
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.0011 Validation Accuracy:0.579000
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy:0.601600
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.0018 Validation Accuracy:0.603600
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy:0.602600
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0019 Validation Accuracy:0.608600
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0015 Validation Accuracy:0.592000
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy:0.603400
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0067 Validation Accuracy:0.576800
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.0010 Validation Accuracy:0.602400
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0040 Validation Accuracy:0.606800
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0012 Validation Accuracy:0.587200
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy:0.604800
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.0011 Validation Accuracy:0.603200
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.605800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy:0.605000
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy:0.599200
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy:0.610200
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy:0.603600
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.597000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy:0.605400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy:0.601200
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.0013 Validation Accuracy:0.603800
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy:0.604200
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy:0.600600
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0024 Validation Accuracy:0.605200
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0022 Validation Accuracy:0.593800
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy:0.606600
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy:0.604400
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.0005 Validation Accuracy:0.611200
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy:0.603600
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0008 Validation Accuracy:0.602400
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy:0.604400
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy:0.601200
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy:0.607600
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy:0.608000
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.0011 Validation Accuracy:0.592600
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy:0.605000
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy:0.607400
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy:0.595600
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy:0.591200
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy:0.603800
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.604400
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy:0.605600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0112 Validation Accuracy:0.599000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy:0.595600
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy:0.594200
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy:0.597200
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy:0.599400
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0011 Validation Accuracy:0.597800
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy:0.602000
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0016 Validation Accuracy:0.604800
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.597200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy:0.600400
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.604000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy:0.592200
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.0013 Validation Accuracy:0.602800
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy:0.592200
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy:0.594200
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.602600
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy:0.602200
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.596200
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.594200
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy:0.587200
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.593800
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy:0.598400
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.609200
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.591600
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy:0.595400
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.608200
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0044 Validation Accuracy:0.598600
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.605600
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy:0.583000
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.0111 Validation Accuracy:0.592600
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.607400
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.611600
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.598000
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy:0.591000
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.0007 Validation Accuracy:0.593600
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.597400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.608800
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.603400
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.580400
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.0014 Validation Accuracy:0.598200
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.607400
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.606200
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.605200
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy:0.596000
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy:0.601200
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.613400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy:0.610200
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.599800
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.593000
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0014 Validation Accuracy:0.595600
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.606200
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.607800
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy:0.595600
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.585400
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.598600
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.615000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.608600
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.610600
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy:0.593400
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.599000
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.609000
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.606400
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.609400
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.597600
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy:0.609400
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.606800
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.610200
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.600800
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0039 Validation Accuracy:0.601800
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy:0.599000
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.603800
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.604400
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.607400
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.605600
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0008 Validation Accuracy:0.597000
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.605000
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy:0.608400
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.606400
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.594600
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy:0.606600
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.602000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0013 Validation Accuracy:0.606200
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.608600
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.600600
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.610800
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.601200
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.601200
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0030 Validation Accuracy:0.602600
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.592400
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy:0.611800
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.601800
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.610400
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.607800
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.605200
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.603600
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0016 Validation Accuracy:0.610600
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.610000
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy:0.595000
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.594600
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy:0.598000
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.595600
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.587000
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.602600
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy:0.600800
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy:0.607000
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.601600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy:0.596400
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.602000
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.607800
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy:0.602400
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.597600
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.604400
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.596800
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy:0.606200
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.602400
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.609600
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.608000
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.596800
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.599000
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.594600
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.603800
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.604800
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.608600
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.594600
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy:0.593600
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.603400
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.592600
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.601200
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.601800
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0030 Validation Accuracy:0.592000
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.603600
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.604600
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.602800
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.600200
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.598600
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.607800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.606000
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.602000
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.599000
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy:0.596000
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.601200
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.591400
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy:0.601600
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.604200
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.598000
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.601800
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.599000
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.599400
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.597800
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.593600
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy:0.597800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.601200
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.601400
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy:0.600000
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.593200
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy:0.601200
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.606600
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.597400
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.598000
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.599200
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.604800
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.601000
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.606000
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.600800
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy:0.597400
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.604400
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.596800
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.600400
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.596800
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.604000
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.593000
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.608400
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.598000
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.598600
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.598400
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.603200
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.603800
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.595200
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.600200
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.604800
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.0032 Validation Accuracy:0.601200
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.605800
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.593200
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.594200
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy:0.594200
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy:0.594800
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.594000
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.593800
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.597400
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.600000
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.605200
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy:0.595000
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy:0.597000
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.603800
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.0011 Validation Accuracy:0.604800
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.604800
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.602600
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.0009 Validation Accuracy:0.588800
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.592800
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy:0.601000
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.601400
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy:0.597400
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.592800
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.602800
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.604600
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy:0.595800
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.603400
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.604600
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.597400
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy:0.596000
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.600800
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.602400
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.591200
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.603000
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.595000
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.599400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy:0.591200
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.593200
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.603000
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.601200
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.598600
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.598800
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy:0.600000
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy:0.600800
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.597000
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.600800
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy:0.603800
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.600400
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.605400
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.601800
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.602600
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy:0.587400
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.600000
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.603600
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy:0.599400
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.596200
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.596400
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.587200
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.0011 Validation Accuracy:0.590200
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.0013 Validation Accuracy:0.602600
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy:0.601000
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.600600
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.603400
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.600200
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.606400
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.599400
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.593800
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.594400
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.607200
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.599600
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.603200
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy:0.606800
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.601200
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.601400
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.590600
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy:0.591000
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.0046 Validation Accuracy:0.588200
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy:0.594600
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy:0.593200
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy:0.587400
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy:0.596600

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.59560546875

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
